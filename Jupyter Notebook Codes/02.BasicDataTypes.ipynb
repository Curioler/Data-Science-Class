# %%
#jupyter nbconvert --ClearOutputPreprocessor.enabled=True --clear-output *.ipynb
#jupyter nbconvert --ClearOutputPreprocessor.enabled=True --inplace Notebook.ipynb

#comment: Understanding the datatypes

#Numeric Data Types
a = 5
print(a, "is of type", type(a))
# Out:
# 5 is of type <class 'int'>

# %%
b = 2.3
print(b, "is of type", type(b))
# Out:
# 2.3 is of type <class 'float'>

# %%
c = 1+2j
print(c, "is of type", type(c))
# Out:
# (1+2j) is of type <class 'complex'>

# %%
print("Is", c, "a complex number?", isinstance(1+2j,complex))
# Out:
# Is (1+2j) a complex number? True

# %%
#String type

greeting = "Hello World!"
print("Greeting: ", greeting)
print("\n")
print(greeting, "is of type", type(greeting))
# Out:
# Greeting:  Hello World!
#
#
# Hello World! is of type <class 'str'>

# %%
#Boolean Type

p=True
q = False
print(type(p))
# Out:
# <class 'bool'>

# %%
# Arithmatic Operators

x = 5
y = 10
m = 2
n = 37

op_sum = x + y
op_mult = x * y
op_sub = x - y
op_div = x / y
op_mod = y % x
op_exp = y**x
op_fl = x // m

print(op_sum)
# Out:
# 15

# %%
#Comparison Operators

comp_eq = (x == y)
comp_neq = (x != y)
comp_gt = (x > y)
comp_lt = (x < y)
comp_gte = (x >= y)
comp_lte = (x <= y)

print(comp_neq)
# Out:
# True

# %%
# Assignment operator

z = x + y

#Add and: m = m + x

m += x

#Substract and: m = m - x
m -= x

#Multiply and: m = m * x

m *= x

#Divide and: m = m / x
m /= x

#Modulus and: n = n % x
n %= x

#Exponent and: m = m**x

m **= x

#Floor division and: n = n // x
n //= x

# %%
#Logical operators

#and
x == 5 and y < 10

#or 
x == 5 or y < 10

#not
not(x == 5 and y < 10)

# %%
#Identity operators

#is

x is y

x is not y

# %%
#Membership operators

sentence = "I know all the basic data types in python"

#in: to check if a valaue/variable is available in the sequence

print("Python" in sentence)

1 in [2,3,4,5]

#not in: to check if a valaue/variable is available in the sequence

print("data" not in sentence)

10 not in [2,3,4,5]
# Out:
# False
# False
# True
