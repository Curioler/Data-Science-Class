# %%
print("Hello World!")

# %%
print()

# %%
# Passing two objects in print
a = 3.14
print(a)
print("a =", a)

# %%
#Print on a new line

print("Python is fun!","\n", "And I'm loving it...")

# %%
print("Python is fun!","\n And I'm loving it...")

# %%
print("Python is fun!","\nAnd I'm loving it...")
